# %% [markdown]
# - This Notebook pulls information about the weather by City

# %%
# !sudo pip3 install geocoder
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# Insert the directory
import sys
sys.path.insert(0,'/content/gdrive/My Drive/Colab Notebooks/Project3')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Import your module or file
import pandas as pd
import geocoder, requests, json

# %%
wc = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Project3/world_cities.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-00650c95ef32> in <module>()
# ----> 1 wc = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Project3/world_cities.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
eu = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Project3/europe_cities_pop.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-816225cb731a> in <module>()
# ----> 1 eu = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Project3/europe_cities_pop.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#@title Country Selection { run: "auto" }
Country = "Venezuela" #@param ["Germany", "Venezuela","Spain","Andorra"]
cities_df = list(wc.set_index('country').loc[Country].name)
cities_df
# Out:
# ['La Asunción',
#  'Anaco',
#  'Alto Barinas',
#  'Zaraza',
#  'Yaritagua',
#  'Villa de Cura',
#  'Villa Bruzual',
#  'Valle de La Pascua',
#  'Valera',
#  'Valencia',
#  'Upata',
#  'Turmero',
#  'Tucupita',
#  'Trujillo',
#  'Tinaquillo',
#  'Táriba',
#  'Santa Teresa',
#  'Santa Rita',
#  'Santa Elena de Uairén',
#  'San Mateo',
#  'San Juan de los Morros',
#  'San Juan de Colón',
#  'San José de Guanipa',
#  'San Joaquín',
#  'San Felipe',
#  'San Cristóbal',
#  'San Carlos del Zulia',
#  'San Carlos',
#  'San Antonio del Táchira',
#  'San Antonio de Los Altos',
#  'Rubio',
#  'La Villa del Rosario',
#  'Quíbor',
#  'Punto Fijo',
#  'Punta Cardón',
#  'Puerto La Cruz',
#  'Puerto Cabello',
#  'Puerto Ayacucho',
#  'Porlamar',
#  'Petare',
#  'Palo Negro',
#  'Ocumare del Tuy',
#  'Nirgua',
#  'Mucumpiz',
#  'Morón',
#  'Mérida',
#  'Mariara',
#  'Maracay',
#  'Maracaibo',
#  'Maiquetía',
#  'Machiques',
#  'Los Teques',
#  'Los Rastrojos',
#  'Los Dos Caminos',
# ...

# %%
eu
# Out:
#                  name         country       pop
# 0              Moscow          Russia  10381222
# 1              London  United Kingdom   8961989
# 2    Saint Petersburg          Russia   5028000
# 3              Berlin         Germany   3426354
# 4              Madrid           Spain   3255944
# ..                ...             ...       ...
# 495         Ussuriysk          Russia    157068
# 496          Tiraspol         Moldova    157000
# 497              Pecs         Hungary    156649
# 498              Ruse        Bulgaria    156238
# 499         Salamanca           Spain    155619
#
# [500 rows x 3 columns]

# %%
#@title Country Selection { run: "auto" }
Country = "Austria" #@param ["Germany","Spain","Andorra","Austria"]
eu_cities_df = list(eu.set_index('country').loc[Country].name)
eu_cities_df
# Out:
# ['Vienna', 'Graz', 'Linz', 'Favoriten', 'Donaustadt', 'Floridsdorf']

# %% [markdown]
#  - The next code is to get information from geonames

# %%
# g = geocoder.geonames('Paris', maxRows=5, country=['FR', 'US'], key='jlma_ve84')
# print([(r.address, r.country) for r in g])

# %%
g = geocoder.geonames('cumana', key='jlma_ve84')
#g.url
g.geojson['features'][0]['geometry']['coordinates']
# Out:
# ['-64.18256', '10.45397']

# %% [markdown]
# *   The next code is to get information from weather

# %%
API_KEY ='99f8d4c989deaf8aee14356ee7e31030'

# %%
url = f"http://api.openweathermap.org/data/2.5/forecast?q={Country}&appid={API_KEY}&units=metric"

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.json()#['list'][1]['weather'][0]['main']
# Out:
# {'city': {'coord': {'lat': 47.3333, 'lon': 13.3333},
#   'country': 'AT',
#   'id': 2782113,
#   'name': 'Austria',
#   'population': 0,
#   'sunrise': 1654657863,
#   'sunset': 1654714835,
#   'timezone': 7200},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 44},
#    'dt': 1654689600,
#    'dt_txt': '2022-06-08 12:00:00',
#    'main': {'feels_like': 16.78,
#     'grnd_level': 864,
#     'humidity': 45,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'temp': 17.77,
#     'temp_kf': -0.92,
#     'temp_max': 18.69,
#     'temp_min': 17.77},
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'visibility': 10000,
#    'weather': [{'description': 'scattered clouds',
#      'icon': '03d',
#      'id': 802,
#      'main': 'Clouds'}],
#    'wind': {'deg': 14, 'gust': 2.34, 'speed': 1.66}},
#   {'clouds': {'all': 53},
#    'dt': 1654700400,
#    'dt_txt': '2022-06-08 15:00:00',
#    'main': {'feels_like': 17,
#     'grnd_level': 863,
#     'humidity': 46,
# ...

# %%
# empty lists that the loop will fill with values
login = []
repo = []
event_type = []

for i in range(len(github_response)):
    # add the login value to the login list
    login.append(github_response[i]['actor']['login'])
    # add the repo name to the repo list
    repo.append(github_response[i]['repo']['name'])
    # add the event type to the event_type list
    event_type.append(github_response[i]['type'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-7becf62c78e8> in <module>()
#       4 event_type = []
#       5
# ----> 6 for i in range(len(github_response)):
#       7     # add the login value to the login list
#       8     login.append(github_response[i]['actor']['login'])
#
# NameError: name 'github_response' is not defined
